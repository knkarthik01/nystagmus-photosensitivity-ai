# %% [markdown]
# <a href="https://colab.research.google.com/github/knkarthik01/nystagmus-photosensitivity-ai/blob/main/notebooks/1_data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📓 1_Data_Preprocessing.ipynb
#
# Create synthetic dataset for training our model.

# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Step 2: Generate synthetic data

# Simulate environmental brightness and eye movement variance
data = pd.DataFrame({
    'brightness_level': np.random.uniform(100, 1000, 500),
    'eye_movement_variance': np.random.uniform(0, 10, 500),
    'photosensitivity_risk': np.random.choice([0, 1], 500)
})

data.head()
# Out:
#    brightness_level  eye_movement_variance  photosensitivity_risk
# 0        511.312495               4.666193                      1
# 1        653.949431               4.707197                      1
# 2        899.021510               4.966507                      1
# 3        458.092018               0.732631                      1
# 4        111.660922               9.996755                      0

# %%
# Step 3: Visualize synthetic data
plt.scatter(data['brightness_level'], data['eye_movement_variance'], c=data['photosensitivity_risk'])
plt.xlabel('Brightness Level')
plt.ylabel('Eye Movement Variance')
plt.title('Synthetic Data for Photosensitivity Risk')
plt.show()

# %%
# Step 4: Save the preprocessed data
data.to_csv('preprocessed_data.csv', index=False)
print('✅ Data saved as preprocessed_data.csv')
# Out:
# ✅ Data saved as preprocessed_data.csv
